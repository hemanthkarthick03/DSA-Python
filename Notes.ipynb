# %% [markdown]
# # Tricks

# %% [markdown]
# Total subarrays containing
# ```python
# arr[i] = (i + 1) × (n − i)
# ```
#
# Odd-length subarrays
# ```python
# arr[i] = ((i + 1) × (n − i) + 1) // 2
# ```
